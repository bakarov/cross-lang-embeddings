# %%
from os import walk, path
from gensim.models import KeyedVectors
from pandas import DataFrame, read_csv, concat
from scipy.spatial.distance import cosine
from scipy.stats import spearmanr
import numpy as np
from collections import defaultdict
from random import sample
from pickle import load

# %% [markdown]
# # Additional data

# %%
def check_occurrence(*words):
    for word in words:  
        if counts[word] < counts_threshold_lower or counts[word] >= counts_threshold_upper:
            return False
    return True

# %%
with open(path.join('..', 'embeddings-evaluation', 'word-analogy', 'counts.pickle'), 'rb') as f:
    counts = load(f)

# %% [markdown]
# # Load dataset

# %% [markdown]
# ## 1. Word similarity

# %%
path_to_en_ru = path.join('..', 'word-benchmarks', 'intrinsic', 'word-similarity', 'cross-lingual', 'en-ru')

english_russian_word_similarity = [
                (path.join(path_to_en_ru, 'simverb-3500.csv'), 'SimVerb-3074'),
                (path.join(path_to_en_ru, 'men.csv'), 'MEN-1146'),
                (path.join(path_to_en_ru, 'rw.csv'), 'RareWord-968'),
                (path.join(path_to_en_ru, 'simlex999.csv'), 'SimLex-739'),
                (path.join(path_to_en_ru, 'mturk-771.csv'), 'MTurk-551'),
                (path.join(path_to_en_ru, 'semeval-2017.csv'), 'SemEval-243'),
                (path.join(path_to_en_ru, 'wordsim353-rel.csv'), 'WordRel-193'),
                (path.join(path_to_en_ru, 'wordsim353-sim.csv'), 'WordSim-193'),
                (path.join(path_to_en_ru, 'verb-143.csv'), 'Verb-115'),
                (path.join(path_to_en_ru, 'yp-130.csv'), 'YP-111'),
                (path.join('..', 'word-benchmarks', 'rg-65.csv'), 'RG-54'),
                (path.join('..', 'word-benchmarks', 'mc-30.csv'), 'MC-28'),
                ]

# %% [markdown]
# ## 2. Word analogy

# %%
'../word-benchmarks/intrinsic/word-analogy/monolingual/en/'

# %%
temp_analogies = defaultdict(lambda: [])
ru_en_analogies = defaultdict(lambda: [])
en_ru_analogies = defaultdict(lambda: [])
type_id = 'type'
word_1_id = 'word1'
word_2_id = 'word2'
word_3_id = 'word3'

russian = read_csv(path.join('..', 'word-benchmarks', 'intrinsic', 'word-analogy', 'monolingual', \
                             'ru', 'google-analogies.csv'))
english = read_csv(path.join('..', 'word-benchmarks', 'intrinsic', 'word-analogy', 'monolingual', \
                             'en', 'google-analogies.csv'))
semantic_cats = russian.category.unique()[:5]

for value in english.type.unique():
    if value in semantic_cats:
        for ind, item in english.loc[english[type_id] == value].iterrows():
            ru_en_analogies[value].append((item[word_1_id].lower(), (russian.loc[ind][word_1_id].lower(),\
                                                                   russian.loc[ind][word_2_id].lower(),\
                                                                   russian.loc[ind][word_3_id].lower())))
            en_ru_analogies[value].append((russian.loc[ind][word_2_id].lower(), (item[word_1_id].lower(),\
                                                                               item[word_2_id].lower(),\
                                                                               item[word_3_id].lower())))

# %%
counts_threshold_lower = 500
counts_threshold_upper = 10000

for key, value in ru_en_analogies.items():
    for item in value:
        target = item[0][0]
        word1 = item[1][0]
        word2 = item[1][1]
        word3 = item[1][2]
        if check_occurrence(word1, word2, word3):
            temp_analogies[key].append(item)

# %%
sample_amount = 150

ru_en_analogies = defaultdict(lambda: [])

for key, value in temp_analogies.items():
    if len(value) < sample_amount:
        print('{}: dropped'.format(key))
        continue
    ru_en_analogies[key] = sample(value, sample_amount)
# Out:
# family: dropped

# %%
length_dict = {key: len(value) for key, value in ru_en_analogies.items()}
length_dict
# Out:
# {'capital-common-countries': 150,
#  'capital-world': 150,
#  'currency': 150,
#  'city-in-state': 150}

# %% [markdown]
# # Calculate extrinsic scores

# %%
def get_word_vector(word, model, vector_size=300):
    if len(word.split(' ')) == 1:
        return model[word]
    else:
        vector = np.zeros(shape=model.vector_size)
        for subword in word.split(' '):
            vector = np.add(vector, modefrom scipy.spatial import KDTreel[subword])
        return vector / len(word.split(' '))

# %%
def calculate_cosines(dataset, src_embeddings, trg_embeddings, verbose=False):
    dataset_len = len(dataset)
    vector_sims = []
    human_sims = []
    for i, m in dataset.iterrows():
        try:
            vector_sims.append(1 - cosine(get_word_vector(m['word1'].lower(), src_embeddings),
                                          get_word_vector(m['word2'].lower(), trg_embeddings)))
            human_sims.append(m['similarity'])
        except KeyError:
            continue
    if verbose:
        print('Percent of dropped = {:2.1f}%, amount of remanining words = {}'.format((dataset_len - len(human_sims))/dataset_len*100, len(human_sims)))
    return np.array(vector_sims), np.array(human_sims)

# %%
length_dict = {key: len(value) for key, value in ru_en_analogies.items()}
length_dict
# Out:
# {'capital-common-countries': 506,
#  'capital-world': 4524,
#  'currency': 866,
#  'city-in-state': 2467,
#  'family': 506}

# %%
sample_amount = 500
new_analogies = defaultdict(lambda: [])

for key, value in ru_en_analogies.items():
    new_analogies[key] = sample(value, 500)

# %% [markdown]
# # Main

# %%
values = defaultdict(lambda: defaultdict(lambda: []))
k = 10

for key, value in res_2.items():
    for key_2, value_2 in value.items():
        for key_3, value_3 in value_2.items():
            if int(key_3) == k:
                values[key][key_2] = value_3
                
results_k = DataFrame(values).transpose()

# %%
results_k.sort_values('capital-common-countries', ascending=False)
# Out:
#                                                     capital-common-countries  \
# bnc-araneum_upos_skipgram_300_2_2018                                0.525692
# wiki-araneum_upos_skipgram_300_2_2018                               0.525692
# googlenews-araneum_upos_skipgram_300_2_2018                         0.525692
# commoncrawl-araneum_upos_skipgram_300_2_2018                        0.525692
# gigaword-araneum_upos_skipgram_300_2_2018                           0.525692
# commoncrawl-web_upos_cbow_300_20_2017                               0.347826
# googlenews-web_upos_cbow_300_20_2017                                0.347826
# gigaword-web_upos_cbow_300_20_2017                                  0.347826
# wiki-web_upos_cbow_300_20_2017                                      0.347826
# bnc-web_upos_cbow_300_20_2017                                       0.347826
# googlenews-news_upos_cbow_300_2_2017                                0.193676
# commoncrawl-news_upos_cbow_300_2_2017                               0.193676
# gigaword-news_upos_cbow_300_2_2017                                  0.193676
# bnc-news_upos_cbow_300_2_2017                                       0.193676
# wiki-news_upos_cbow_300_2_2017                                      0.193676
# wiki-taiga_upos_skipgram_300_2_2018                                 0.169960
# gigaword-taiga_upos_skipgram_300_2_2018                             0.169960
# bnc-taiga_upos_skipgram_300_2_2018                                  0.169960
# commoncrawl-taiga_upos_skipgram_300_2_2018                          0.169960
# googlenews-taiga_upos_skipgram_300_2_2018                           0.169960
# bnc-ruscorpora_upos_skipgram_300_5_2018                             0.000000
# wiki-ruwikiruscorpora-superbigrams_skipgram_300...                  0.000000
# wiki-ruscorpora_upos_skipgram_300_5_2018                            0.000000
# commoncrawl-ruwikiruscorpora-superbigrams_skipg...                  0.000000
# bnc-ruwikiruscorpora-superbigrams_skipgram_300_...                  0.000000
# googlenews-ruwikiruscorpora-superbigrams_skipgr...                  0.000000
# googlenews-ruscorpora_upos_skipgram_300_5_2018                      0.000000
# gigaword-ruscorpora_upos_skipgram_300_5_2018                        0.000000
# commoncrawl-ruscorpora_upos_skipgram_300_5_2018                     0.000000
# gigaword-ruwikiruscorpora-superbigrams_skipgram...                  0.000000
#
#                                                     capital-world  \
# bnc-araneum_upos_skipgram_300_2_2018                     0.124131
# wiki-araneum_upos_skipgram_300_2_2018                    0.124131
# googlenews-araneum_upos_skipgram_300_2_2018              0.124131
# commoncrawl-araneum_upos_skipgram_300_2_2018             0.124131
# gigaword-araneum_upos_skipgram_300_2_2018                0.124131
# commoncrawl-web_upos_cbow_300_20_2017                    0.085743
# googlenews-web_upos_cbow_300_20_2017                     0.085743
# gigaword-web_upos_cbow_300_20_2017                       0.085743
# wiki-web_upos_cbow_300_20_2017                           0.085743
# bnc-web_upos_cbow_300_20_2017                            0.085743
# googlenews-news_upos_cbow_300_2_2017                     0.025167
# commoncrawl-news_upos_cbow_300_2_2017                    0.025167
# gigaword-news_upos_cbow_300_2_2017                       0.025167
# bnc-news_upos_cbow_300_2_2017                            0.025167
# wiki-news_upos_cbow_300_2_2017                           0.025167
# wiki-taiga_upos_skipgram_300_2_2018                      0.027452
# gigaword-taiga_upos_skipgram_300_2_2018                  0.027452
# bnc-taiga_upos_skipgram_300_2_2018                       0.027452
# commoncrawl-taiga_upos_skipgram_300_2_2018               0.027452
# googlenews-taiga_upos_skipgram_300_2_2018                0.027452
# bnc-ruscorpora_upos_skipgram_300_5_2018                  0.000000
# wiki-ruwikiruscorpora-superbigrams_skipgram_300...       0.000000
# wiki-ruscorpora_upos_skipgram_300_5_2018                 0.000000
# commoncrawl-ruwikiruscorpora-superbigrams_skipg...       0.000000
# bnc-ruwikiruscorpora-superbigrams_skipgram_300_...       0.000000
# googlenews-ruwikiruscorpora-superbigrams_skipgr...       0.000000
# googlenews-ruscorpora_upos_skipgram_300_5_2018           0.000000
# gigaword-ruscorpora_upos_skipgram_300_5_2018             0.000000
# commoncrawl-ruscorpora_upos_skipgram_300_5_2018          0.000000
# gigaword-ruwikiruscorpora-superbigrams_skipgram...       0.000000
#
#                                                     city-in-state  currency  \
# bnc-araneum_upos_skipgram_300_2_2018                     0.015734  0.095170
# wiki-araneum_upos_skipgram_300_2_2018                    0.015734  0.095170
# googlenews-araneum_upos_skipgram_300_2_2018              0.015734  0.095170
# commoncrawl-araneum_upos_skipgram_300_2_2018             0.015734  0.095170
# gigaword-araneum_upos_skipgram_300_2_2018                0.015734  0.095170
# commoncrawl-web_upos_cbow_300_20_2017                    0.006205  0.045906
# googlenews-web_upos_cbow_300_20_2017                     0.006205  0.045906
# gigaword-web_upos_cbow_300_20_2017                       0.006205  0.045906
# wiki-web_upos_cbow_300_20_2017                           0.006205  0.045906
# bnc-web_upos_cbow_300_20_2017                            0.006205  0.045906
# googlenews-news_upos_cbow_300_2_2017                     0.008484  0.013740
# commoncrawl-news_upos_cbow_300_2_2017                    0.008484  0.013740
# gigaword-news_upos_cbow_300_2_2017                       0.008484  0.013740
# bnc-news_upos_cbow_300_2_2017                            0.008484  0.013740
# wiki-news_upos_cbow_300_2_2017                           0.008484  0.013740
# wiki-taiga_upos_skipgram_300_2_2018                      0.014717  0.093023
# gigaword-taiga_upos_skipgram_300_2_2018                  0.014717  0.093023
# bnc-taiga_upos_skipgram_300_2_2018                       0.014717  0.093023
# commoncrawl-taiga_upos_skipgram_300_2_2018               0.014717  0.093023
# googlenews-taiga_upos_skipgram_300_2_2018                0.014717  0.093023
# bnc-ruscorpora_upos_skipgram_300_5_2018                  0.000000  0.000000
# wiki-ruwikiruscorpora-superbigrams_skipgram_300...       0.000000  0.000000
# wiki-ruscorpora_upos_skipgram_300_5_2018                 0.000000  0.000000
# commoncrawl-ruwikiruscorpora-superbigrams_skipg...       0.000000  0.000000
# bnc-ruwikiruscorpora-superbigrams_skipgram_300_...       0.000000  0.000000
# googlenews-ruwikiruscorpora-superbigrams_skipgr...       0.000000  0.000000
# googlenews-ruscorpora_upos_skipgram_300_5_2018           0.000000  0.000000
# gigaword-ruscorpora_upos_skipgram_300_5_2018             0.000000  0.000000
# commoncrawl-ruscorpora_upos_skipgram_300_5_2018          0.000000  0.000000
# gigaword-ruwikiruscorpora-superbigrams_skipgram...       0.000000  0.000000
#
#                                                       family
# bnc-araneum_upos_skipgram_300_2_2018                0.057143
# wiki-araneum_upos_skipgram_300_2_2018               0.057143
# googlenews-araneum_upos_skipgram_300_2_2018         0.057143
# commoncrawl-araneum_upos_skipgram_300_2_2018        0.057143
# gigaword-araneum_upos_skipgram_300_2_2018           0.057143
# commoncrawl-web_upos_cbow_300_20_2017               0.028571
# googlenews-web_upos_cbow_300_20_2017                0.028571
# gigaword-web_upos_cbow_300_20_2017                  0.028571
# wiki-web_upos_cbow_300_20_2017                      0.028571
# bnc-web_upos_cbow_300_20_2017                       0.028571
# googlenews-news_upos_cbow_300_2_2017                0.000000
# commoncrawl-news_upos_cbow_300_2_2017               0.000000
# gigaword-news_upos_cbow_300_2_2017                  0.000000
# bnc-news_upos_cbow_300_2_2017                       0.000000
# wiki-news_upos_cbow_300_2_2017                      0.000000
# wiki-taiga_upos_skipgram_300_2_2018                 0.108571
# gigaword-taiga_upos_skipgram_300_2_2018             0.108571
# bnc-taiga_upos_skipgram_300_2_2018                  0.108571
# commoncrawl-taiga_upos_skipgram_300_2_2018          0.108571
# googlenews-taiga_upos_skipgram_300_2_2018           0.108571
# bnc-ruscorpora_upos_skipgram_300_5_2018             0.000000
# wiki-ruwikiruscorpora-superbigrams_skipgram_300...  0.000000
# wiki-ruscorpora_upos_skipgram_300_5_2018            0.000000
# commoncrawl-ruwikiruscorpora-superbigrams_skipg...  0.000000
# bnc-ruwikiruscorpora-superbigrams_skipgram_300_...  0.000000
# googlenews-ruwikiruscorpora-superbigrams_skipgr...  0.000000
# googlenews-ruscorpora_upos_skipgram_300_5_2018      0.000000
# gigaword-ruscorpora_upos_skipgram_300_5_2018        0.000000
# commoncrawl-ruscorpora_upos_skipgram_300_5_2018     0.000000
# gigaword-ruwikiruscorpora-superbigrams_skipgram...  0.000000

# %%
results = DataFrame()
res_2 = defaultdict(lambda: defaultdict(lambda: {}))

for fpath, _, files in walk('../cross-lang/'):
    for file in files:
        filename, file_extension = path.splitext(path.join(fpath, file))
        if file_extension == '.txt':
            language = filename.split('/')[~0]
            model_name = filename.split('/')[2]
            if language == 'vectors-ru':
                vectors_ru = KeyedVectors.load_word2vec_format(path.join(fpath, file))
            if language == 'vectors-en':
                vectors_en = KeyedVectors.load_word2vec_format(path.join(fpath, file))
                intrinsic_metrics = DataFrame({model_name: [spearmanr(*calculate_cosines(read_csv(dataset),
                                                                                          vectors_en,
                                                                                          vectors_ru,
                                                                                          verbose=False))[0]
                                                             for dataset, _ in english_russian_word_similarity]},
                                             index=[name for _, name in english_russian_word_similarity]).transpose()
                results = concat([intrinsic_metrics, results], axis= 0)
                print('{}: done\n'.format(model_name))
                p_at_k_list = [1, 5, 10]
                for p_at_k in p_at_k_list:
                    for key in ru_en_analogies.keys():
                        res = 0
                        amo = 0
                        for pair in ru_en_analogies[key]:
                            try:
                                vector = vectors_ru[pair[1][0]] - vectors_ru[pair[1][1]] + vectors_ru[pair[1][2]]
                                amo += 1
                                if pair[0] in [q[0].lower() for q in vectors_en.similar_by_vector(vector)[:p_at_k]]:
                                    res += 1
                            except:
                                pass
                        res_2[model_name][key][p_at_k] = res/amo
# Out:
# commoncrawl-araneum_upos_skipgram_300_2_2018: done
#
# googlenews-news_upos_cbow_300_2_2017: done
#
# gigaword-web_upos_cbow_300_20_2017: done
#
# googlenews-ruscorpora_upos_skipgram_300_5_2018: done
#
# gigaword-ruscorpora_upos_skipgram_300_5_2018: done
#
# wiki-ruscorpora_upos_skipgram_300_5_2018: done
#
# wiki-araneum_upos_skipgram_300_2_2018: done
#
# googlenews-web_upos_cbow_300_20_2017: done
#
# wiki-web_upos_cbow_300_20_2017: done
#
# commoncrawl-taiga_upos_skipgram_300_2_2018: done
#
# googlenews-taiga_upos_skipgram_300_2_2018: done
#
# googlenews-ruwikiruscorpora-superbigrams_skipgram_300_2_2018: done
#
# gigaword-araneum_upos_skipgram_300_2_2018: done
#
# commoncrawl-news_upos_cbow_300_2_2017: done
#
# gigaword-news_upos_cbow_300_2_2017: done
#
# bnc-ruwikiruscorpora-superbigrams_skipgram_300_2_2018: done
#
# bnc-news_upos_cbow_300_2_2017: done
#
# bnc-taiga_upos_skipgram_300_2_2018: done
#
# gigaword-taiga_upos_skipgram_300_2_2018: done
#
# commoncrawl-ruwikiruscorpora-superbigrams_skipgram_300_2_2018: done
#
# wiki-ruwikiruscorpora-superbigrams_skipgram_300_2_2018: done
#
# bnc-web_upos_cbow_300_20_2017: done
#
# wiki-taiga_upos_skipgram_300_2_2018: done
#
# commoncrawl-web_upos_cbow_300_20_2017: done
#
# bnc-araneum_upos_skipgram_300_2_2018: done
#
# googlenews-araneum_upos_skipgram_300_2_2018: done
#
# bnc-ruscorpora_upos_skipgram_300_5_2018: done
#
# commoncrawl-ruscorpora_upos_skipgram_300_5_2018: done
#
# gigaword-ruwikiruscorpora-superbigrams_skipgram_300_2_2018: done
#
# wiki-news_upos_cbow_300_2_2017: done

# %%
results.sort_values('SimLex-739', ascending=False)
# Out:
#                                                     SimVerb-3074  MEN-1146  \
# commoncrawl-araneum_upos_skipgram_300_2_2018            0.141711       NaN
# wiki-araneum_upos_skipgram_300_2_2018                   0.141711       NaN
# googlenews-araneum_upos_skipgram_300_2_2018             0.141711       NaN
# bnc-araneum_upos_skipgram_300_2_2018                    0.141711       NaN
# gigaword-araneum_upos_skipgram_300_2_2018               0.141711       NaN
# bnc-taiga_upos_skipgram_300_2_2018                      0.096937       NaN
# commoncrawl-taiga_upos_skipgram_300_2_2018              0.096937       NaN
# wiki-taiga_upos_skipgram_300_2_2018                     0.096937       NaN
# googlenews-taiga_upos_skipgram_300_2_2018               0.096937       NaN
# gigaword-taiga_upos_skipgram_300_2_2018                 0.096937       NaN
# wiki-ruscorpora_upos_skipgram_300_5_2018                0.252562       NaN
# googlenews-ruscorpora_upos_skipgram_300_5_2018          0.252562       NaN
# gigaword-ruscorpora_upos_skipgram_300_5_2018            0.252562       NaN
# bnc-ruscorpora_upos_skipgram_300_5_2018                 0.252562       NaN
# commoncrawl-ruscorpora_upos_skipgram_300_5_2018         0.252562       NaN
# gigaword-web_upos_cbow_300_20_2017                      0.067640       NaN
# bnc-web_upos_cbow_300_20_2017                           0.067640       NaN
# commoncrawl-web_upos_cbow_300_20_2017                   0.067640       NaN
# wiki-web_upos_cbow_300_20_2017                          0.067640       NaN
# googlenews-web_upos_cbow_300_20_2017                    0.067640       NaN
# commoncrawl-ruwikiruscorpora-superbigrams_skipg...      0.033572       NaN
# bnc-ruwikiruscorpora-superbigrams_skipgram_300_...      0.033572       NaN
# gigaword-ruwikiruscorpora-superbigrams_skipgram...      0.033572       NaN
# wiki-ruwikiruscorpora-superbigrams_skipgram_300...      0.033572       NaN
# googlenews-ruwikiruscorpora-superbigrams_skipgr...      0.033572       NaN
# googlenews-news_upos_cbow_300_2_2017                    0.030295       NaN
# wiki-news_upos_cbow_300_2_2017                          0.030295       NaN
# commoncrawl-news_upos_cbow_300_2_2017                   0.030295       NaN
# bnc-news_upos_cbow_300_2_2017                           0.030295       NaN
# gigaword-news_upos_cbow_300_2_2017                      0.030295       NaN
#
#                                                     RareWord-968  SimLex-739  \
# commoncrawl-araneum_upos_skipgram_300_2_2018            0.442495    0.238718
# wiki-araneum_upos_skipgram_300_2_2018                   0.442495    0.238718
# googlenews-araneum_upos_skipgram_300_2_2018             0.442495    0.238718
# bnc-araneum_upos_skipgram_300_2_2018                    0.442495    0.238718
# gigaword-araneum_upos_skipgram_300_2_2018               0.442495    0.238718
# bnc-taiga_upos_skipgram_300_2_2018                      0.299269    0.217732
# commoncrawl-taiga_upos_skipgram_300_2_2018              0.299269    0.217732
# wiki-taiga_upos_skipgram_300_2_2018                     0.299269    0.217732
# googlenews-taiga_upos_skipgram_300_2_2018               0.299269    0.217732
# gigaword-taiga_upos_skipgram_300_2_2018                 0.299269    0.217732
# wiki-ruscorpora_upos_skipgram_300_5_2018               -0.102598    0.181453
# googlenews-ruscorpora_upos_skipgram_300_5_2018         -0.102598    0.181453
# gigaword-ruscorpora_upos_skipgram_300_5_2018           -0.102598    0.181453
# bnc-ruscorpora_upos_skipgram_300_5_2018                -0.102598    0.181453
# commoncrawl-ruscorpora_upos_skipgram_300_5_2018        -0.102598    0.181453
# gigaword-web_upos_cbow_300_20_2017                      0.274354    0.165375
# bnc-web_upos_cbow_300_20_2017                           0.274354    0.165375
# commoncrawl-web_upos_cbow_300_20_2017                   0.274354    0.165375
# wiki-web_upos_cbow_300_20_2017                          0.274354    0.165375
# googlenews-web_upos_cbow_300_20_2017                    0.274354    0.165375
# commoncrawl-ruwikiruscorpora-superbigrams_skipg...      0.097376    0.133928
# bnc-ruwikiruscorpora-superbigrams_skipgram_300_...      0.097376    0.133928
# gigaword-ruwikiruscorpora-superbigrams_skipgram...      0.097376    0.133928
# wiki-ruwikiruscorpora-superbigrams_skipgram_300...      0.097376    0.133928
# googlenews-ruwikiruscorpora-superbigrams_skipgr...      0.097376    0.133928
# googlenews-news_upos_cbow_300_2_2017                   -0.088775    0.131201
# wiki-news_upos_cbow_300_2_2017                         -0.088775    0.131201
# commoncrawl-news_upos_cbow_300_2_2017                  -0.088775    0.131201
# bnc-news_upos_cbow_300_2_2017                          -0.088775    0.131201
# gigaword-news_upos_cbow_300_2_2017                     -0.088775    0.131201
#
#                                                     MTurk-551  SemEval-243  \
# commoncrawl-araneum_upos_skipgram_300_2_2018         0.541967     0.637047
# wiki-araneum_upos_skipgram_300_2_2018                0.541967     0.637047
# googlenews-araneum_upos_skipgram_300_2_2018          0.541967     0.637047
# bnc-araneum_upos_skipgram_300_2_2018                 0.541967     0.637047
# gigaword-araneum_upos_skipgram_300_2_2018            0.541967     0.637047
# bnc-taiga_upos_skipgram_300_2_2018                   0.447814     0.484390
# commoncrawl-taiga_upos_skipgram_300_2_2018           0.447814     0.484390
# wiki-taiga_upos_skipgram_300_2_2018                  0.447814     0.484390
# googlenews-taiga_upos_skipgram_300_2_2018            0.447814     0.484390
# gigaword-taiga_upos_skipgram_300_2_2018              0.447814     0.484390
# wiki-ruscorpora_upos_skipgram_300_5_2018             0.145682     0.302761
# googlenews-ruscorpora_upos_skipgram_300_5_2018       0.145682     0.302761
# gigaword-ruscorpora_upos_skipgram_300_5_2018         0.145682     0.302761
# bnc-ruscorpora_upos_skipgram_300_5_2018              0.145682     0.302761
# commoncrawl-ruscorpora_upos_skipgram_300_5_2018      0.145682     0.302761
# gigaword-web_upos_cbow_300_20_2017                   0.425265     0.535976
# bnc-web_upos_cbow_300_20_2017                        0.425265     0.535976
# commoncrawl-web_upos_cbow_300_20_2017                0.425265     0.535976
# wiki-web_upos_cbow_300_20_2017                       0.425265     0.535976
# googlenews-web_upos_cbow_300_20_2017                 0.425265     0.535976
# commoncrawl-ruwikiruscorpora-superbigrams_skipg...   0.277361     0.390479
# bnc-ruwikiruscorpora-superbigrams_skipgram_300_...   0.277361     0.390479
# gigaword-ruwikiruscorpora-superbigrams_skipgram...   0.277361     0.390479
# wiki-ruwikiruscorpora-superbigrams_skipgram_300...   0.277361     0.390479
# googlenews-ruwikiruscorpora-superbigrams_skipgr...   0.277361     0.390479
# googlenews-news_upos_cbow_300_2_2017                 0.255455     0.319226
# wiki-news_upos_cbow_300_2_2017                       0.255455     0.319226
# commoncrawl-news_upos_cbow_300_2_2017                0.255455     0.319226
# bnc-news_upos_cbow_300_2_2017                        0.255455     0.319226
# gigaword-news_upos_cbow_300_2_2017                   0.255455     0.319226
#
#                                                     WordRel-193  WordSim-193  \
# commoncrawl-araneum_upos_skipgram_300_2_2018           0.530806     0.672836
# wiki-araneum_upos_skipgram_300_2_2018                  0.530806     0.672836
# googlenews-araneum_upos_skipgram_300_2_2018            0.530806     0.672836
# bnc-araneum_upos_skipgram_300_2_2018                   0.530806     0.672836
# gigaword-araneum_upos_skipgram_300_2_2018              0.530806     0.672836
# bnc-taiga_upos_skipgram_300_2_2018                     0.333250     0.527843
# commoncrawl-taiga_upos_skipgram_300_2_2018             0.333250     0.527843
# wiki-taiga_upos_skipgram_300_2_2018                    0.333250     0.527843
# googlenews-taiga_upos_skipgram_300_2_2018              0.333250     0.527843
# gigaword-taiga_upos_skipgram_300_2_2018                0.333250     0.527843
# wiki-ruscorpora_upos_skipgram_300_5_2018               0.129878     0.396923
# googlenews-ruscorpora_upos_skipgram_300_5_2018         0.129878     0.396923
# gigaword-ruscorpora_upos_skipgram_300_5_2018           0.129878     0.396923
# bnc-ruscorpora_upos_skipgram_300_5_2018                0.129878     0.396923
# commoncrawl-ruscorpora_upos_skipgram_300_5_2018        0.129878     0.396923
# gigaword-web_upos_cbow_300_20_2017                     0.412438     0.556892
# bnc-web_upos_cbow_300_20_2017                          0.412438     0.556892
# commoncrawl-web_upos_cbow_300_20_2017                  0.412438     0.556892
# wiki-web_upos_cbow_300_20_2017                         0.412438     0.556892
# googlenews-web_upos_cbow_300_20_2017                   0.412438     0.556892
# commoncrawl-ruwikiruscorpora-superbigrams_skipg...     0.325159     0.420394
# bnc-ruwikiruscorpora-superbigrams_skipgram_300_...     0.325159     0.420394
# gigaword-ruwikiruscorpora-superbigrams_skipgram...     0.325159     0.420394
# wiki-ruwikiruscorpora-superbigrams_skipgram_300...     0.325159     0.420394
# googlenews-ruwikiruscorpora-superbigrams_skipgr...     0.325159     0.420394
# googlenews-news_upos_cbow_300_2_2017                   0.320280     0.504650
# wiki-news_upos_cbow_300_2_2017                         0.320280     0.504650
# commoncrawl-news_upos_cbow_300_2_2017                  0.320280     0.504650
# bnc-news_upos_cbow_300_2_2017                          0.320280     0.504650
# gigaword-news_upos_cbow_300_2_2017                     0.320280     0.504650
#
#                                                     Verb-115    YP-111  \
# commoncrawl-araneum_upos_skipgram_300_2_2018        0.341336  0.344530
# wiki-araneum_upos_skipgram_300_2_2018               0.341336  0.344530
# googlenews-araneum_upos_skipgram_300_2_2018         0.341336  0.344530
# bnc-araneum_upos_skipgram_300_2_2018                0.341336  0.344530
# gigaword-araneum_upos_skipgram_300_2_2018           0.341336  0.344530
# bnc-taiga_upos_skipgram_300_2_2018                  0.229580  0.221071
# commoncrawl-taiga_upos_skipgram_300_2_2018          0.229580  0.221071
# wiki-taiga_upos_skipgram_300_2_2018                 0.229580  0.221071
# googlenews-taiga_upos_skipgram_300_2_2018           0.229580  0.221071
# gigaword-taiga_upos_skipgram_300_2_2018             0.229580  0.221071
# wiki-ruscorpora_upos_skipgram_300_5_2018                 NaN -1.000000
# googlenews-ruscorpora_upos_skipgram_300_5_2018           NaN -1.000000
# gigaword-ruscorpora_upos_skipgram_300_5_2018             NaN -1.000000
# bnc-ruscorpora_upos_skipgram_300_5_2018                  NaN -1.000000
# commoncrawl-ruscorpora_upos_skipgram_300_5_2018          NaN -1.000000
# gigaword-web_upos_cbow_300_20_2017                  0.217490  0.229476
# bnc-web_upos_cbow_300_20_2017                       0.217490  0.229476
# commoncrawl-web_upos_cbow_300_20_2017               0.217490  0.229476
# wiki-web_upos_cbow_300_20_2017                      0.217490  0.229476
# googlenews-web_upos_cbow_300_20_2017                0.217490  0.229476
# commoncrawl-ruwikiruscorpora-superbigrams_skipg...  0.026082  0.040585
# bnc-ruwikiruscorpora-superbigrams_skipgram_300_...  0.026082  0.040585
# gigaword-ruwikiruscorpora-superbigrams_skipgram...  0.026082  0.040585
# wiki-ruwikiruscorpora-superbigrams_skipgram_300...  0.026082  0.040585
# googlenews-ruwikiruscorpora-superbigrams_skipgr...  0.026082  0.040585
# googlenews-news_upos_cbow_300_2_2017                0.327444  0.293198
# wiki-news_upos_cbow_300_2_2017                      0.327444  0.293198
# commoncrawl-news_upos_cbow_300_2_2017               0.327444  0.293198
# bnc-news_upos_cbow_300_2_2017                       0.327444  0.293198
# gigaword-news_upos_cbow_300_2_2017                  0.327444  0.293198
#
#                                                        RG-54     MC-28
# commoncrawl-araneum_upos_skipgram_300_2_2018        0.441808  0.590257
# wiki-araneum_upos_skipgram_300_2_2018               0.441808  0.590257
# googlenews-araneum_upos_skipgram_300_2_2018         0.441808  0.590257
# bnc-araneum_upos_skipgram_300_2_2018                0.441808  0.590257
# gigaword-araneum_upos_skipgram_300_2_2018           0.441808  0.590257
# bnc-taiga_upos_skipgram_300_2_2018                  0.424951  0.532143
# commoncrawl-taiga_upos_skipgram_300_2_2018          0.424951  0.532143
# wiki-taiga_upos_skipgram_300_2_2018                 0.424951  0.532143
# googlenews-taiga_upos_skipgram_300_2_2018           0.424951  0.532143
# gigaword-taiga_upos_skipgram_300_2_2018             0.424951  0.532143
# wiki-ruscorpora_upos_skipgram_300_5_2018                 NaN       NaN
# googlenews-ruscorpora_upos_skipgram_300_5_2018           NaN       NaN
# gigaword-ruscorpora_upos_skipgram_300_5_2018             NaN       NaN
# bnc-ruscorpora_upos_skipgram_300_5_2018                  NaN       NaN
# commoncrawl-ruscorpora_upos_skipgram_300_5_2018          NaN       NaN
# gigaword-web_upos_cbow_300_20_2017                  0.379134  0.359781
# bnc-web_upos_cbow_300_20_2017                       0.379134  0.359781
# commoncrawl-web_upos_cbow_300_20_2017               0.379134  0.359781
# wiki-web_upos_cbow_300_20_2017                      0.379134  0.359781
# googlenews-web_upos_cbow_300_20_2017                0.379134  0.359781
# commoncrawl-ruwikiruscorpora-superbigrams_skipg...  0.217933  0.422709
# bnc-ruwikiruscorpora-superbigrams_skipgram_300_...  0.217933  0.422709
# gigaword-ruwikiruscorpora-superbigrams_skipgram...  0.217933  0.422709
# wiki-ruwikiruscorpora-superbigrams_skipgram_300...  0.217933  0.422709
# googlenews-ruwikiruscorpora-superbigrams_skipgr...  0.217933  0.422709
# googlenews-news_upos_cbow_300_2_2017                0.364906  0.528330
# wiki-news_upos_cbow_300_2_2017                      0.364906  0.528330
# commoncrawl-news_upos_cbow_300_2_2017               0.364906  0.528330
# bnc-news_upos_cbow_300_2_2017                       0.364906  0.528330
# gigaword-news_upos_cbow_300_2_2017                  0.364906  0.528330
